# %% [markdown]
# # Medical Cost Personal Insurance Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
print("the rows and columns in the dataset:", df.columns)
print("dimensions in the dataset:", df.shape)
# Out:
# the rows and columns in the dataset: Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')
# dimensions in the dataset: (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
#checking if null values
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()     # evaluation of data type of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()    # statistical analysis of data
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Conversion
# converting the string values to numerical data

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['sex']=df['sex'].map({'female':0,'male':1})
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    0  27.900         0    yes  southwest  16884.92400
# 1      18    1  33.770         1     no  southeast   1725.55230
# 2      28    1  33.000         3     no  southeast   4449.46200
# 3      33    1  22.705         0     no  northwest  21984.47061
# 4      32    1  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    1  30.970         3     no  northwest  10600.54830
# 1334   18    0  31.920         0     no  northeast   2205.98080
# 1335   18    0  36.850         0     no  southeast   1629.83350
# 1336   21    0  25.800         0     no  southwest   2007.94500
# 1337   61    0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['smoker']=df['smoker'].map({'yes':1,"no":0})
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df['region']=df['region'].map({'southwest':1,'southeast':2,'northwest':3,'northeast':4})
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       1  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       3  21984.47061
# 4      32    1  28.880         0       0       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       3  10600.54830
# 1334   18    0  31.920         0       0       4   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       1   2007.94500
# 1337   61    0  29.070         0       1       3  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Ploting the variables of the dataset

# %%
# box plot to show the variation of variables 
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df, palette="Set3")
plt.title('Distribution of Physicochemical Variables')
plt.show()

# %%
#Regplot
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<17:
        plt.subplot(5,4,p)
        sns.regplot(x="charges",y=i,data=df,color="r")
        plt.xlabel("charges")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
# lineplot
plt.figure(figsize=(15,8))
sns.lineplot(data=df.iloc[:,:-1])
plt.ylabel("charges")
plt.title("the general trend of all values")
plt.show()

# %% [markdown]
# # Z score

# %%
from scipy.stats import zscore
out_features=df[["age","sex","bmi","children","smoker","region"]]
z=np.abs(zscore(out_features))    #
z
# Out:
#            age       sex       bmi  children    smoker    region
# 0     1.438764  1.010519  0.453320  0.908614  1.970587  1.343905
# 1     1.509965  0.989591  0.509621  0.078767  0.507463  0.438495
# 2     0.797954  0.989591  0.383307  1.580926  0.507463  0.438495
# 3     0.441948  0.989591  1.305531  0.908614  0.507463  0.466915
# 4     0.513149  0.989591  0.292556  0.908614  0.507463  0.466915
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463  0.466915
# 1334  1.509965  1.010519  0.206139  0.908614  0.507463  1.372326
# 1335  1.509965  1.010519  1.014878  0.908614  0.507463  0.438495
# 1336  1.296362  1.010519  0.797813  0.908614  0.507463  1.343905
# 1337  1.551686  1.010519  0.261388  0.908614  1.970587  0.466915
#
# [1338 rows x 6 columns]

# %%
np.where(z>3)
# Out:
# (array([  32,   71,  116,  166,  413,  425,  438,  568,  640,  847,  877,
#          932,  937,  969,  984, 1047, 1085, 1116, 1130, 1245, 1272, 1317],
#        dtype=int64),
#  array([3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2],
#        dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (1316, 7)

# %%
print("old dataframe: ",df.shape[0])
print("new dataframe: ",df1.shape[0])
# Out:
# old dataframe:  1338
# new dataframe:  1316

# %%
print("data loss percentage:",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage: 1.6442451420029895

# %%
df1
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       1  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       3  21984.47061
# 4      32    1  28.880         0       0       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       3  10600.54830
# 1334   18    0  31.920         0       0       4   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       1   2007.94500
# 1337   61    0  29.070         0       1       3  29141.36030
#
# [1316 rows x 7 columns]

# %%
q1=out_features.quantile(0.25)
q3=out_features.quantile(0.75)
IQR=q3-q1
df2=df[~((df<(q1-1.5*IQR))|(df>(q3+1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       3  21984.47061
# 4      32    1  28.880         0       0       3   3866.85520
# 5      31    0  25.740         0       0       2   3756.62160
# ...   ...  ...     ...       ...     ...     ...          ...
# 1332   52    0  44.700         3       0       1  11411.68500
# 1333   50    1  30.970         3       0       3  10600.54830
# 1334   18    0  31.920         0       0       4   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       1   2007.94500
#
# [1058 rows x 7 columns]

# %%
print("data loss percentage by IQR:",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage by IQR: 20.92675635276532

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019 -0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185 -0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750 -0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673 -0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000  0.002181  0.787251
# region   -0.002127 -0.004588 -0.157566 -0.016569  0.002181  1.000000  0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251  0.006208  1.000000

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True,fmt='0.2f')
# Out:
# <Axes: >

# %%
df.corr().charges.sort_values()
# Out:
# region      0.006208
# sex         0.057292
# children    0.067998
# bmi         0.198341
# age         0.299008
# smoker      0.787251
# charges     1.000000
# Name: charges, dtype: float64

# %% [markdown]
# # Checking the skewness of the data

# %%
plt.figure(figsize=(20,25),facecolor="green")
plotnumber=1
for column in df:
    if plotnumber<=18:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Featuring the x and y

# %%
x=df1.drop(['charges'],axis=1)
y=df1['charges']
print("feature dimensions",x.shape)
print("label dimension",y.shape)
# Out:
# feature dimensions (1316, 6)
# label dimension (1316,)

# %% [markdown]
# # Feature Scaling using Standard Scalarisation
# for evaluation of the data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.441444 -1.006098 -0.453768 -0.928234  1.959141 -1.352089
# 1    -1.512509  0.993939  0.527239 -0.038536 -0.510428 -0.446568
# 2    -0.801858  0.993939  0.398555  1.740862 -0.510428 -0.446568
# 3    -0.446533  0.993939 -1.321967 -0.928234 -0.510428  0.458954
# 4    -0.517598  0.993939 -0.289988 -0.928234 -0.510428  0.458954
# ...        ...       ...       ...       ...       ...       ...
# 1311  0.761574  0.993939  0.059297  1.740862 -0.510428  0.458954
# 1312 -1.512509 -1.006098  0.218063 -0.928234 -0.510428  1.364475
# 1313 -1.512509 -1.006098  1.041975 -0.928234 -0.510428 -0.446568
# 1314 -1.299314 -1.006098 -0.804724 -0.928234 -0.510428 -1.352089
# 1315  1.543290 -1.006098 -0.258235 -0.928234  1.959141  0.458954
#
# [1316 rows x 6 columns]

# %% [markdown]
# # Checking Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#    VIF values  Features
# 0    1.018969       age
# 1    1.008550       sex
# 2    1.043397       bmi
# 3    1.004829  children
# 4    1.007649    smoker
# 5    1.026415    region

# %% [markdown]
# # Modelling
# for finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
# finding the best random state
maxacc=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)   # to find difference between the predicted and actual value
    if acc>maxacc: 
        maxacc=acc
        maxrs=i
print("Maximum score is",maxacc,"on Random state",maxrs)
# Out:
# Maximum score is 0.8095951183237355 on Random state 38

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxrs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_LR))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error',mean_squared_error(y_test,pred_LR))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score:  0.8095951183237355
# R2 score on training data:  72.18617400679355
# Mean Absolute Error 3990.64686424241
# Mean Squared Error 30532219.52743317
# Root mean squared Error 5525.596757584937

# %%
plt.figure
plt.scatter(x=pred_LR,y=y_test,color="r")
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("linear regression",fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_RFR))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error',mean_squared_error(y_test,pred_RFR))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score:  0.8707804716888976
# R2 score on training data:  97.46932490435191
# Mean Absolute Error 2663.50543115757
# Mean Squared Error 20720892.084763
# Root mean squared Error 4552.020659527261

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_knn))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error',mean_squared_error(y_test,pred_knn))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score:  0.8440766083488421
# R2 score on training data:  85.99554671972729
# Mean Absolute Error 3154.9904275098734
# Mean Squared Error 25002968.313855745
# Root mean squared Error 5000.29682257521

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_GBR))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error',mean_squared_error(y_test,pred_GBR))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score:  0.8962877428805239
# R2 score on training data:  89.26054894404024
# Mean Absolute Error 2464.3936408525356
# Mean Squared Error 16630694.41381962
# Root mean squared Error 4078.074841615786

# %%
ls=Lasso()
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
pred_train=ls.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_ls))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_ls))
print('Mean Squared Error',mean_squared_error(y_test,pred_ls))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# R2 score:  0.8095880808017689
# R2 score on training data:  72.18616957567833
# Mean Absolute Error 3990.457490105584
# Mean Squared Error 30533348.023529083
# Root mean squared Error 5525.698871955391

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_rd))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error',mean_squared_error(y_test,pred_rd))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score:  0.8094715035156299
# R2 score on training data:  72.18608454715553
# Mean Absolute Error 3993.255181760871
# Mean Squared Error 30552041.679179996
# Root mean squared Error 5527.390132710011

# %%
from sklearn.tree import DecisionTreeRegressor 

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_dtr))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error',mean_squared_error(y_test,pred_dtr))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score:  0.7596036318216792
# R2 score on training data:  100.0
# Mean Absolute Error 2862.7993886835447
# Mean Squared Error 38548563.57778516
# Root mean squared Error 6208.748954321245

# %%
from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
pred_svr=dtr.predict(x_test)
pred_train=svr.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_svr))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_svr))
print('Mean Squared Error',mean_squared_error(y_test,pred_svr))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score:  0.7596036318216792
# R2 score on training data:  -9.49035012479662
# Mean Absolute Error 2862.7993886835447
# Mean Squared Error 38548563.57778516
# Root mean squared Error 6208.748954321245

# %%
from sklearn.ensemble import ExtraTreesRegressor

etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2 score: ',r2_score(y_test,pred_etr))
print('R2 score on training data: ',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,pred_etr))
print('Mean Squared Error',mean_squared_error(y_test,pred_etr))
print('Root mean squared Error',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score:  0.8485224021475576
# R2 score on training data:  100.0
# Mean Absolute Error 2700.3343073390643
# Mean Squared Error 24290066.67477449
# Root mean squared Error 6208.748954321245

# %% [markdown]
# # Cross Validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
score =cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.76083173 0.70903994 0.77840442 0.72604513 0.76143299]
# 0.7471508430420551
# Difference between R2 score and cross validation score:  6.244427528168039

# %%
score1=cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [0.85424568 0.77868382 0.86561246 0.82377525 0.85387883]
# 0.8352392075569183
# Difference between R2 score and cross validation score:  3.5541264131979333

# %%
 score2 =cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_knn)-score2.mean())*100)
# Out:
# [0.82139209 0.75698491 0.83949648 0.8033858  0.81280207]
# 0.806812269270978
# Difference between R2 score and cross validation score:  3.7264339077864084

# %%
score3 =cross_val_score(GBR,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [0.87151685 0.79813149 0.88772168 0.84541888 0.86179662]
# 0.8529171050142746
# Difference between R2 score and cross validation score:  14.91368998384688

# %%
score4 =cross_val_score(ls,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_ls)-score4.mean())*100)
# Out:
# [0.76083951 0.70907086 0.77838556 0.72604469 0.76143662]
# 0.7471554471025387
# Difference between R2 score and cross validation score:  6.243263369923024

# %%
score5 =cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_rd)-score5.mean())*100)
# Out:
# [0.76083967 0.70914187 0.7782823  0.72612955 0.76138872]
# 0.7471564189273934
# Difference between R2 score and cross validation score:  6.231508458823654

# %%
score6 =cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_dtr)-score6.mean())*100)
# Out:
# [0.77545531 0.65375902 0.66679228 0.70319062 0.67434004]
# 0.6947074549459884
# Difference between R2 score and cross validation score:  6.4896176875690825

# %%
score7 =cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_svr)-score7.mean())*100)
# Out:
# [-0.11311862 -0.10554673 -0.07029546 -0.1005942  -0.1075108 ]
# -0.0994131612093693
# Difference between R2 score and cross validation score:  85.90167930310486

# %%
score8 =cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score: ",(r2_score(y_test,pred_etr)-score8.mean())*100)
# Out:
# [0.83448386 0.74608428 0.84523182 0.81095854 0.83827142]
# 0.8150059835825647
# Difference between R2 score and cross validation score:  3.351641856499288

# %%
# hence we are considering the GBR due to high accuracy in result

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Hyper Parameter Tunning
param={'alpha':[1.0,0.05,0.4,2],'fit_intercept':[True,False],'solver':['auto','svd','cholesky','lsqr','sag','saga','lbfgs'],'positive':[False,True],'random_state':[1,4,10,20]}
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 1,
#  'solver': 'auto'}

# %%
Model=Ridge(alpha=0.05,fit_intercept=True,positive=False,random_state=1,solver='lsqr')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('r2_score: ',r2_score(y_test,pred))
print('Mean Absolute error:',mean_absolute_error(y_test,pred))
print('Mean Squared error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score:  0.8095647258673954
# Mean Absolute error: 3992.7404810677012
# Mean Squared error: 30537093.084984783
# Root Mean Squared Error:  5526.037738288147

# %%
import joblib
#joblib.dump(Model,"insurance.pkl")

# %%
import pickle
filename='insurance.pkl'
pickle.dump(Model,open(filename,'wb'))

# %%
import pickle 
loaded_model=pickle.load(open('insurance.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 80.95647258673954

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])
conclusion
# Out:
#                    0            1            2            3             4    \
# Predicted  5736.846445  4152.485857  9733.013979  6351.112659  37971.543122
# original   4661.286350  2867.119600  6571.544000  4149.736000  46599.108400
#
#                     5            6            7             8            9    \
# Predicted  16431.110376  2716.258496  6068.790542  11547.876715  6951.874578
# original   12982.874700  1720.353700  3021.809150  20878.784430  9264.797000
#
#            ...           385           386           387           388  \
# Predicted  ...  12929.029089  14183.412564  11874.321236  13610.955971
# original   ...   9386.161300   8733.229250  12797.209620   7650.773750
#
#                    389          390          391           392          393  \
# Predicted  5931.644297  12693.02143  2176.106266  23249.772757  3807.622434
# original   1146.796600  10806.83900  1815.875900  13747.872350  1263.249000
#
#                    394
# Predicted  3527.741547
# original   1137.011000
#
# [2 rows x 395 columns]

# %% [markdown]
# # checking the model

# %%
data={'age':40,'sex':1,'bmi':40.30,'children':4,'smoker':1,'region':2}
df1=pd.DataFrame(data,index=[0])
df1
# Out:
#    age  sex   bmi  children  smoker  region
# 0   40    1  40.3         4       1       2

# %%
new_predict=Model.predict(df1)
print(new_predict)
# Out:
# [248047.53719365]
