# %% [markdown]
# # Assignment No.: 4
# Web Scrapping

# %% [markdown]
# # Question no.: 1
# Scrape the details of most viewed videos on YouTube from Wikipedia. Url
# = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)
# Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
vedio=[]
try:
    vedio_list=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
    for i in vedio_list:
        vedio.append(i.text)
except NoSuchElementException:
        vedio.append("-") 
vedio
# Out:
# ['"Baby Shark Dance"[6]',
#  '"Despacito"[9]',
#  '"Johny Johny Yes Papa"[17]',
#  '"Bath Song"[18]',
#  '"Shape of You"[19]',
#  '"See You Again"[22]',
#  '"Wheels on the Bus"[27]',
#  '"Phonics Song with Two Words"[28]',
#  '"Uptown Funk"[29]',
#  '"Learning Colors – Colorful Eggs on a Farm"[30]',
#  '"Gangnam Style"[31]',
#  '"Masha and the Bear – Recipe for Disaster"[36]',
#  '"Dame Tu Cosita"[37]',
#  '"Axel F"[38]',
#  '"Sugar"[39]',
#  '"Counting Stars"[40]',
#  '"Roar"[41]',
#  '"Baa Baa Black Sheep"[42]',
#  '"Waka Waka (This Time for Africa)"[43]',
#  '"Lakdi Ki Kathi"[44]',
#  '"Sorry"[45]',
#  '"Thinking Out Loud"[46]',
#  '"Humpty the train on a fruits ride"[47]',
#  '"Dark Horse"[48]',
#  '"Perfect"[49]',
#  '"Let Her Go"[50]',
#  '"Faded"[51]',
#  '"Shree Hanuman Chalisa"[52]',
#  '"Girls Like You"[53]',
#  '"Lean On"[54]',
#  "Pinkfong Baby Shark - Kids' Songs & Stories",
#  'Luis Fonsi',
#  'Wiz Khalifa',
#  'Psy',
#  'Justin Bieber',
#  'Lady Gaga',
#  'HDCYT',
# ...

# %%
# Out:
# 377

# %%
name=[]
try:
    name_list=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
    for i in name_list:
        name.append(i.text)
except NoSuchElementException:
        name.append("-") 
name
# Out:
# ["Pinkfong Baby Shark - Kids' Songs & Stories",
#  'Luis Fonsi',
#  "LooLoo Kids - Nursery Rhymes and Children's Songs",
#  'Cocomelon - Nursery Rhymes',
#  'Ed Sheeran',
#  'Wiz Khalifa',
#  'Cocomelon - Nursery Rhymes',
#  'ChuChu TV Nursery Rhymes & Kids Songs',
#  'Mark Ronson',
#  'Miroshka TV',
#  'officialpsy',
#  'Get Movies',
#  'Ultra Records',
#  'Crazy Frog',
#  'Maroon 5',
#  'OneRepublic',
#  'Katy Perry',
#  'Cocomelon - Nursery Rhymes',
#  'Shakira',
#  'Jingle Toons',
#  'Justin Bieber',
#  'Ed Sheeran',
#  'Kiddiestv Hindi - Nursery Rhymes & Kids Songs',
#  'Katy Perry',
#  'Ed Sheeran',
#  'Passenger',
#  'Alan Walker',
#  'T-Series Bhakti Sagar',
#  'Maroon 5',
#  'Major Lazer Official',
#  '7,046,700,000',
#  '2,993,700,000',
#  '2,894,000,000',
#  '803,700,000',
#  '245,400,000',
#  '178,400,000',
#  '128,900,000',
#  '118,900,000',
#  '92,600,000',
#  '78,400,000',
#  '76,600,000',
#  '10,600,000',
#  '4,300,000',
#  '2,700,000',
#  '3,400,000',
# ...

# %%
date=[]
try:
    date_list=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")
    for i in date_list:
        date.append(i.text)
except NoSuchElementException:
        date.append("-") 
date
# Out:
# ['June 17, 2016',
#  'January 12, 2017',
#  'October 8, 2016',
#  'May 2, 2018',
#  'January 30, 2017',
#  'April 6, 2015',
#  'May 24, 2018',
#  'March 6, 2014',
#  'November 19, 2014',
#  'February 27, 2018',
#  'July 15, 2012',
#  'January 31, 2012',
#  'April 5, 2018',
#  'June 16, 2009',
#  'January 14, 2015',
#  'May 31, 2013',
#  'September 5, 2013',
#  'June 25, 2018',
#  'June 4, 2010',
#  'June 14, 2018',
#  'October 22, 2015',
#  'October 7, 2014',
#  'January 26, 2018',
#  'February 20, 2014',
#  'November 9, 2017',
#  'July 25, 2012',
#  'December 3, 2015',
#  'May 10, 2011',
#  'May 31, 2018',
#  'March 22, 2015',
#  'November 2, 2020',
#  'August 4, 2017',
#  'July 10, 2017',
#  'November 24, 2012',
#  'July 16, 2010',
#  'April 14, 2010',
#  'October 25, 2009',
#  'May 2, 2009',
#  'July 17, 2008',
#  'March 15, 2008',
#  'March 1, 2008',
#  'May 19, 2006',
#  'March 12, 2006',
#  'February 18, 2006',
#  'January 21, 2006',
#  'January 9, 2006',
# ...

# %%
view=[]
try:
    view_list=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
    for i in view_list:
        view.append(i.text)
except NoSuchElementException:
        view.append("-") 
print("the views in billions : ",view)
# Out:
# the views in billions :  ['13.65', '8.32', '6.84', '6.50', '6.14', '6.09', '5.71', '5.57', '5.09', '5.01', '4.96', '4.57', '4.48', '4.16', '3.97', '3.92', '3.91', '3.84', '3.78', '3.76', '3.74', '3.69', '3.63', '3.63', '3.60', '3.56', '3.55', '3.54', '3.52', '3.50', 'June 17, 2016', 'January 12, 2017', 'April 6, 2015', 'July 15, 2012', 'February 19, 2010', 'November 24, 2009', 'May 22, 2007', 'April 6, 2006', 'February 27, 2007', 'April 6, 2006', 'April 9, 2007', 'April 6, 2006', 'November 28, 2005', 'January 31, 2006', 'December 1, 2005', 'December 18, 2005', 'October 21, 2005', 'October 5, 2005']

# %%
df=pd.DataFrame({"name":name,"vedio":vedio,"date of publish":date,"views":view})
df
# Out:
#                                                  name  \
# 0         Pinkfong Baby Shark - Kids' Songs & Stories
# 1                                          Luis Fonsi
# 2   LooLoo Kids - Nursery Rhymes and Children's Songs
# 3                          Cocomelon - Nursery Rhymes
# 4                                          Ed Sheeran
# 5                                         Wiz Khalifa
# 6                          Cocomelon - Nursery Rhymes
# 7               ChuChu TV Nursery Rhymes & Kids Songs
# 8                                         Mark Ronson
# 9                                         Miroshka TV
# 10                                        officialpsy
# 11                                         Get Movies
# 12                                      Ultra Records
# 13                                         Crazy Frog
# 14                                           Maroon 5
# 15                                        OneRepublic
# ...

# %% [markdown]
# # Question no. 2:
# Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Series
# B) Place
# C) Date
# D) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
driver=webdriver.Chrome()
driver.get(" https://www.bcci.tv/")

# %%
fixture=driver.find_element(By.XPATH,"//*[@id='imw-international-men']/a[2]").click()

# %%
series=[]
try:
    series_list=driver.find_elements(By.XPATH,"//h5[@class='match-tournament-name ng-binding']")
    for i in series_list:
        series.append(i.text)
except NoSuchElementException:
        series.append("-") 
series
# Out:
# ['AUSTRALIA TOUR OF INDIA 2023-24',
#  'QUADRANGULAR MENS U19 ONE DAY SERIES',
#  'QUADRANGULAR MENS U19 ONE DAY SERIES',
#  'AUSTRALIA TOUR OF INDIA 2023-24',
#  'ENGLAND A WOMENS TOUR OF INDIA T20 SERIES',
#  'ENGLAND A WOMENS TOUR OF INDIA T20 SERIES',
#  'AUSTRALIA TOUR OF INDIA 2023-24',
#  'ENGLAND A WOMENS TOUR OF INDIA T20 SERIES',
#  'AUSTRALIA TOUR OF INDIA 2023-24']

# %%
place=[]
try:
    place_list=driver.find_elements(By.XPATH,"//div[@class='col-lg-6 col-md-6 col-sm-12']")
    for i in place_list:
        place.append(i.text)
except NoSuchElementException:
        place.append("-") 
place
# Out:
# ['Greenfield International Stadium, Thiruvananthapuram\nIndia\nAustralia',
#  'CP Ground,Mulapadu, Vijayawada\nEngland U19\nBangladesh U19',
#  'DVR Ground,Mulapadu, Vijayawada\nIndia U19 A\nIndia U19 B',
#  'Barsapara Cricket Stadium, Guwahati\nIndia\nAustralia',
#  'Wankhede Stadium, Mumbai\nIndia A Women\nEngland A Women',
#  'Wankhede Stadium, Mumbai\nIndia A Women\nEngland A Women',
#  'Shaheed Veer Narayan Singh International Cricket Stadium, Raipur\nIndia\nAustralia',
#  'Wankhede Stadium, Mumbai\nIndia A Women\nEngland A Women',
#  'M Chinnaswamy Stadium, Bengaluru\nIndia\nAustralia']

# %%
time=[]
try:
    time_list=driver.find_elements(By.XPATH,"//div[@class='match-date-info']")
    for i in time_list:
        time.append(i.text)
except NoSuchElementException:
        time.append("-") 
time
# Out:
# ['26 NOVEMBER, 2023\n7:00 PM IST',
#  '27 NOVEMBER, 2023\n9:00 AM IST',
#  '27 NOVEMBER, 2023\n9:00 AM IST',
#  '28 NOVEMBER, 2023\n7:00 PM IST',
#  '29 NOVEMBER, 2023\n1:30 PM IST',
#  '1 DECEMBER, 2023\n1:30 PM IST',
#  '1 DECEMBER, 2023\n7:00 PM IST',
#  '3 DECEMBER, 2023\n1:30 PM IST',
#  '3 DECEMBER, 2023\n7:00 PM IST']

# %%
df=pd.DataFrame({"series":series,"Place of match":place,"time and date":time})
df
# Out:
#                                       series  \
# 0            AUSTRALIA TOUR OF INDIA 2023-24
# 1       QUADRANGULAR MENS U19 ONE DAY SERIES
# 2       QUADRANGULAR MENS U19 ONE DAY SERIES
# 3            AUSTRALIA TOUR OF INDIA 2023-24
# 4  ENGLAND A WOMENS TOUR OF INDIA T20 SERIES
# 5  ENGLAND A WOMENS TOUR OF INDIA T20 SERIES
# 6            AUSTRALIA TOUR OF INDIA 2023-24
# 7  ENGLAND A WOMENS TOUR OF INDIA T20 SERIES
# 8            AUSTRALIA TOUR OF INDIA 2023-24
#
#                                       Place of match  \
# 0  Greenfield International Stadium, Thiruvananth...
# 1  CP Ground,Mulapadu, Vijayawada\nEngland U19\nB...
# 2  DVR Ground,Mulapadu, Vijayawada\nIndia U19 A\n...
# 3  Barsapara Cricket Stadium, Guwahati\nIndia\nAu...
# 4  Wankhede Stadium, Mumbai\nIndia A Women\nEngla...
# 5  Wankhede Stadium, Mumbai\nIndia A Women\nEngla...
# 6  Shaheed Veer Narayan Singh International Crick...
# 7  Wankhede Stadium, Mumbai\nIndia A Women\nEngla...
# ...

# %% [markdown]
# # Question no.: 3
# Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details: A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
driver=webdriver.Chrome()
driver.get("http://statisticstimes.com/ ")

# %%
economy_button=driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/button").click()

# %%
india=driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/div/a[3]").click()

# %%
gdp=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a").click()

# %%
state=[]
try:
    state_list=driver.find_elements(By.XPATH,"//td[@class='name']")
    for i in state_list:
        state.append(i.text)
except NoSuchElementException:
        state.append("-") 
state
# Out:
# ['Maharashtra',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Gujarat',
#  'Karnataka',
#  'West Bengal',
#  'Rajasthan',
#  'Andhra Pradesh',
#  'Telangana',
#  'Madhya Pradesh',
#  'Kerala',
#  'Delhi',
#  'Haryana',
#  'Bihar',
#  'Punjab',
#  'Odisha',
#  'Assam',
#  'Chhattisgarh',
#  'Jharkhand',
#  'Uttarakhand',
#  'Jammu & Kashmir',
#  'Himachal Pradesh',
#  'Goa',
#  'Tripura',
#  'Chandigarh',
#  'Puducherry',
#  'Meghalaya',
#  'Sikkim',
#  'Manipur',
#  'Nagaland',
#  'Arunachal Pradesh',
#  'Mizoram',
#  'Andaman & Nicobar Islands',
#  'India',
#  'Maharashtra',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Karnataka',
#  'Gujarat',
#  'West Bengal',
#  'Rajasthan',
#  'Telangana',
#  'Andhra Pradesh',
#  'Madhya Pradesh',
#  'Kerala',
#  'Delhi',
#  'Haryana',
#  'Bihar',
#  'Punjab',
#  'Odisha',
#  'Assam',
#  'Jharkhand',
#  'Chhattisgarh',
#  'Uttarakhand',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Goa',
#  'Tripura',
#  'Chandigarh',
#  'Puducherry',
#  'Meghalaya',
# ...

# %%
states=state[0:66]

# %%
GDP=[]
try:
    GDP_list=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]")
    for i in GDP_list:
        GDP.append(i.text)
except NoSuchElementException:
        GDP.append("-") 
GDP
# Out:
# ['399.921',
#  '247.629',
#  '240.726',
#  '228.290',
#  '226.806',
#  '165.556',
#  '143.179',
#  '131.083',
#  '130.791',
#  '122.977',
#  '118.733',
#  '117.703',
#  '111.519',
#  '80.562',
#  '79.957',
#  '74.098',
#  '47.982',
#  '46.187',
#  '45.145',
#  '37.351',
#  '23.690',
#  '23.369',
#  '11.115',
#  '7.571',
#  '6.397',
#  '5.230',
#  '5.086',
#  '4.363',
#  '4.233',
#  '4.144',
#  '3.737',
#  '3.385',
#  '-',
#  '-',
#  '1,167,776',
#  '1,015,735',
#  '1,035,131',
#  '-',
#  '713,376',
#  '630,693',
#  '594,806',
#  '595,605',
#  '496,798',
#  '-',
#  '568,265',
#  '514,983',
#  '377,276',
#  '374,015',
#  '344,437',
#  '-',
#  '218,232',
#  '210,837',
#  '-',
#  '107,171',
#  '-',
#  '56,810',
#  '35,980',
#  '-',
#  '22,291',
#  '23,564',
#  '18,549',
#  '17,060',
#  '-',
#  '-',
#  '17,797',
#  '-']

# %%
len(GDP)
# Out:
# 66

# %%
GSDP_19_20=[]
try:
    GSDP_19_20_list=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]")
    for i in GSDP_19_20_list:
        GSDP_19_20.append(i.text)
except NoSuchElementException:
        GSDP_19_20.append("-") 
GSDP_19_20
# Out:
# ['-',
#  '1,845,853',
#  '1,687,818',
#  '-',
#  '1,631,977',
#  '1,253,832',
#  '1,020,989',
#  '972,782',
#  '969,604',
#  '906,672',
#  '-',
#  '856,112',
#  '831,610',
#  '611,804',
#  '574,760',
#  '521,275',
#  '-',
#  '329,180',
#  '328,598',
#  '-',
#  '-',
#  '165,472',
#  '80,449',
#  '55,984',
#  '-',
#  '38,253',
#  '36,572',
#  '32,496',
#  '31,790',
#  '-',
#  '-',
#  '26,503',
#  '-',
#  '-',
#  '1,659,210',
#  '1,495,758',
#  '1,476,983',
#  '-',
#  '1,150,711',
#  '916,014',
#  '881,873',
#  '875,429',
#  '827,019',
#  '-',
#  '779,647',
#  '755,790',
#  '562,710',
#  '517,521',
#  '457,757',
#  '-',
#  '301,242',
#  '288,041',
#  '-',
#  '143,063',
#  '-',
#  '72,181',
#  '50,227',
#  '-',
#  '34,823',
#  '32,833',
#  '29,148',
#  '28,391',
#  '-',
#  '-',
#  '24,424',
#  '-']

# %%
len(GSDP_19_20)
# Out:
# 66

# %%
GDP_18_19=[]
try:
    GDP_18_19_list=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]")
    for i in GDP_18_19_list:
        GDP_18_19.append(i.text)
except NoSuchElementException:
        GDP_18_19.append("-") 
GDP_18_19
# Out:
# ['2,632,792',
#  '1,630,208',
#  '1,584,764',
#  '1,502,899',
#  '1,493,127',
#  '1,089,898',
#  '942,586',
#  '862,957',
#  '861,031',
#  '809,592',
#  '781,653',
#  '774,870',
#  '734,163',
#  '530,363',
#  '526,376',
#  '487,805',
#  '315,881',
#  '304,063',
#  '297,204',
#  '245,895',
#  '155,956',
#  '153,845',
#  '73,170',
#  '49,845',
#  '42,114',
#  '34,433',
#  '33,481',
#  '28,723',
#  '27,870',
#  '27,283',
#  '24,603',
#  '22,287',
#  '-',
#  '2,332,992',
#  '1,465,361',
#  '1,404,761',
#  '1,351,553',
#  '1,322,936',
#  '995,502',
#  '845,247',
#  '782,370',
#  '776,140',
#  '737,156',
#  '707,542',
#  '704,529',
#  '666,075',
#  '486,776',
#  '472,506',
#  '428,031',
#  '282,782',
#  '271,990',
#  '266,537',
#  '221,871',
#  '133,303',
#  '129,877',
#  '66,060',
#  '44,835',
#  '37,571',
#  '31,415',
#  '29,544',
#  '25,323',
#  '25,141',
#  '24,534',
#  '22,488',
#  '20,947',
#  '-']

# %%
len(GDP_18_19)
# Out:
# 66

# %%
shares=[]
try:
    shares_list=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]")
    for i in shares_list:
        shares.append(i.text)
except NoSuchElementException:
        shares.append("-") 
shares
# Out:
# ['13.94%',
#  '8.63%',
#  '8.39%',
#  '7.96%',
#  '7.91%',
#  '5.77%',
#  '4.99%',
#  '4.57%',
#  '4.56%',
#  '4.29%',
#  '4.14%',
#  '4.10%',
#  '3.89%',
#  '2.81%',
#  '2.79%',
#  '2.58%',
#  '1.67%',
#  '1.61%',
#  '1.57%',
#  '1.30%',
#  '0.83%',
#  '0.81%',
#  '0.39%',
#  '0.26%',
#  '0.22%',
#  '0.18%',
#  '0.18%',
#  '0.15%',
#  '0.15%',
#  '0.14%',
#  '0.13%',
#  '0.12%',
#  '-',
#  '13.97%',
#  '8.77%',
#  '8.41%',
#  '8.09%',
#  '7.92%',
#  '5.96%',
#  '5.06%',
#  '4.68%',
#  '4.65%',
#  '4.41%',
#  '4.24%',
#  '4.22%',
#  '3.99%',
#  '2.91%',
#  '2.83%',
#  '2.56%',
#  '1.69%',
#  '1.63%',
#  '1.60%',
#  '1.33%',
#  '0.80%',
#  '0.78%',
#  '0.40%',
#  '0.27%',
#  '0.22%',
#  '0.19%',
#  '0.18%',
#  '0.15%',
#  '0.15%',
#  '0.15%',
#  '0.13%',
#  '0.13%',
#  '-']

# %%
len(shares)
# Out:
# 66

# %%
df_gdp=pd.DataFrame({"State":states,"GDP":GDP,"GSDP_19_20":GSDP_19_20,"GSDP_18_19":GDP_18_19,"shares":shares})
df_gdp
# Out:
#                 State      GDP GSDP_19_20 GSDP_18_19  shares
# 0         Maharashtra  399.921          -  2,632,792  13.94%
# 1          Tamil Nadu  247.629  1,845,853  1,630,208   8.63%
# 2       Uttar Pradesh  240.726  1,687,818  1,584,764   8.39%
# 3             Gujarat  228.290          -  1,502,899   7.96%
# 4           Karnataka  226.806  1,631,977  1,493,127   7.91%
# ..                ...      ...        ...        ...     ...
# 61            Manipur   17,060     28,391     25,141   0.15%
# 62             Sikkim        -          -     24,534   0.15%
# 63           Nagaland        -          -     22,488   0.13%
# 64  Arunachal Pradesh   17,797     24,424     20,947   0.13%
# 65            Mizoram        -          -          -       -
#
# [66 rows x 5 columns]

# %% [markdown]
# # Question no.: 4
# Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
driver=webdriver.Chrome()
driver.get(" https://github.com/")

# %%
Title=[]

# %%
try:
    title_list=driver.find_elements(By.XPATH,"//span[@class='Text-sc-17v1xeu-0 qaOIC search-match']")
    for i in title_list:
        Title.append(i.text)
except NoSuchElementException:
        Title.append("-") 
Title
# Out:
# ['vitalets/github-trending-repos',
#  'mbadry1/Trending-Deep-Learning',
#  'QasimWani/LeetHub',
#  'Semigradsky/trending-repositories',
#  'laowch/GithubTrends',
#  'ophobe/trending',
#  'ecrmnn/trending-github',
#  'zhuowenli/githuber',
#  'andygrunwald/TrendingGithub',
#  'andygrunwald/go-trending']

# %%
tit=pd.DataFrame(Title,columns=["title"])
tit
# Out:
#                                title
# 0     vitalets/github-trending-repos
# 1     mbadry1/Trending-Deep-Learning
# 2                  QasimWani/LeetHub
# 3  Semigradsky/trending-repositories
# 4                laowch/GithubTrends
# 5                    ophobe/trending
# 6             ecrmnn/trending-github
# 7                 zhuowenli/githuber
# 8        andygrunwald/TrendingGithub
# 9           andygrunwald/go-trending

# %%
description=[]
try:
    description_list=driver.find_elements(By.XPATH,"//li[@class='Box-sc-g0xbh4-0 gVaQzD']")
    for i in description_list:
        description.append(i.text)
except NoSuchElementException:
        description.append("-") 
description
# Out:
# ['HTML',
#  '2.6k',
#  'Updated on Apr 22',
#  'JavaScript',
#  '3.6k',
#  'Updated 3 days ago',
#  'Python',
#  '605',
#  'Updated on Feb 2, 2020',
#  'JavaScript',
#  '79',
#  'Updated on Oct 3, 2018',
#  'Java',
#  '637',
#  'Updated on Jun 10, 2019',
#  '60',
#  'Updated on Aug 16, 2020',
#  'TypeScript',
#  '60',
#  'Updated on Feb 19',
#  'JavaScript',
#  '474',
#  'Updated on Jul 11',
#  'Go',
#  '111',
#  'Updated 9 days ago',
#  'Go',
#  '137',
#  'Updated on Oct 24']

# %%
len(description)
# Out:
# 29

# %%
df_m=pd.DataFrame((description),columns=["update_date"])
df_m
# Out:
#                 update_date
# 0                      HTML
# 1                      2.6k
# 2         Updated on Apr 22
# 3                JavaScript
# 4                      3.6k
# 5        Updated 3 days ago
# 6                    Python
# 7                       605
# 8    Updated on Feb 2, 2020
# 9                JavaScript
# 10                       79
# 11   Updated on Oct 3, 2018
# 12                     Java
# 13                      637
# 14  Updated on Jun 10, 2019
# 15                       60
# 16  Updated on Aug 16, 2020
# 17               TypeScript
# 18                       60
# 19        Updated on Feb 19
# 20               JavaScript
# 21                      474
# 22        Updated on Jul 11
# 23                       Go
# 24                      111
# 25       Updated 9 days ago
# 26                       Go
# 27                      137
# 28        Updated on Oct 24

# %%
description.insert(15,"")
description
# Out:
# ['HTML',
#  '2.6k',
#  'Updated on Apr 22',
#  'JavaScript',
#  '3.6k',
#  'Updated 3 days ago',
#  'Python',
#  '605',
#  'Updated on Feb 2, 2020',
#  'JavaScript',
#  '79',
#  'Updated on Oct 3, 2018',
#  'Java',
#  '637',
#  'Updated on Jun 10, 2019',
#  '',
#  '60',
#  'Updated on Aug 16, 2020',
#  'TypeScript',
#  '60',
#  'Updated on Feb 19',
#  'JavaScript',
#  '474',
#  'Updated on Jul 11',
#  'Go',
#  '111',
#  'Updated 9 days ago',
#  'Go',
#  '137',
#  'Updated on Oct 24']

# %%
import numpy as np
df=pd.DataFrame(np.array(description).reshape(10,3),columns=["language","count","update_date"])
df
# Out:
#      language count              update_date
# 0        HTML  2.6k        Updated on Apr 22
# 1  JavaScript  3.6k       Updated 3 days ago
# 2      Python   605   Updated on Feb 2, 2020
# 3  JavaScript    79   Updated on Oct 3, 2018
# 4        Java   637  Updated on Jun 10, 2019
# 5                60  Updated on Aug 16, 2020
# 6  TypeScript    60        Updated on Feb 19
# 7  JavaScript   474        Updated on Jul 11
# 8          Go   111       Updated 9 days ago
# 9          Go   137        Updated on Oct 24

# %%
df_new=pd.concat([tit,df],axis=1)
df_new
# Out:
#                                title    language count  \
# 0     vitalets/github-trending-repos        HTML  2.6k
# 1     mbadry1/Trending-Deep-Learning  JavaScript  3.6k
# 2                  QasimWani/LeetHub      Python   605
# 3  Semigradsky/trending-repositories  JavaScript    79
# 4                laowch/GithubTrends        Java   637
# 5                    ophobe/trending                60
# 6             ecrmnn/trending-github  TypeScript    60
# 7                 zhuowenli/githuber  JavaScript   474
# 8        andygrunwald/TrendingGithub          Go   111
# 9           andygrunwald/go-trending          Go   137
#
#                update_date
# 0        Updated on Apr 22
# 1       Updated 3 days ago
# 2   Updated on Feb 2, 2020
# 3   Updated on Oct 3, 2018
# 4  Updated on Jun 10, 2019
# 5  Updated on Aug 16, 2020
# 6        Updated on Feb 19
# 7        Updated on Jul 11
# 8       Updated 9 days ago
# 9        Updated on Oct 24

# %% [markdown]
# # Question no.: 5
# Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the
# following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
driver=webdriver.Chrome()
driver.get("https:/www.billboard.com/")

# %%
explore=driver.find_element(By.XPATH,"//*[@id='main-wrapper']/header/div/div[4]/div/div[1]/div[1]/button").click()

# %%
charts=driver.find_element(By.XPATH,"//*[@id='mega-menu-item-charts']/button").click()

# %%
top_100_songs=driver.find_element(By.XPATH,"//*[@id='main-wrapper']/div[9]/div/div/div/ul/li[1]/ul/li[2]/a").click()

# %%
song=[]
try:
    song_list=driver.find_elements(By.XPATH,"//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
    for i in song_list:
        song.append(i.text)
except NoSuchElementException:
        song.append("-") 
song
# Out:
# ['Cruel Summer',
#  'Paint The Town Red',
#  'All I Want For Christmas Is You',
#  'Snooze',
#  'I Remember Everything',
#  'Greedy',
#  "Rockin' Around The Christmas Tree",
#  "Is It Over Now? (Taylor's Version) [From The Vault]",
#  'Water',
#  'You Broke My Heart',
#  'Jingle Bell Rock',
#  'Last Christmas',
#  'Last Night',
#  "Thinkin' Bout Me",
#  'A Holly Jolly Christmas',
#  'First Person Shooter',
#  'Fast Car',
#  'Agora Hills',
#  'Rich Baby Daddy',
#  'Need A Favor',
#  'Save Me',
#  'Vampire',
#  'Lil Boo Thang',
#  'Fukumean',
#  'Evil Ways',
#  'White Horse',
#  "It's The Most Wonderful Time Of The Year",
#  'IDGAF',
#  'Used To Be Young',
#  'Dance The Night',
#  'Good Good',
#  'Houdini',
#  'Exes',
#  'Let It Snow, Let It Snow, Let It Snow!',
#  'What Was I Made For?',
#  'Stick Season',
#  'Monaco',
#  'Feliz Navidad',
#  'Lose Control',
#  'Dial Drunk',
#  'Underneath The Tree',
#  'The Christmas Song (Merry Christmas To You)',
#  'My Love Mine All Mine',
# ...

# %%
len(song)
# Out:
# 99

# %%
artist_name=[]
try:
    artist_name_list=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
    for i in artist_name_list:
        artist_name.append(i.text)
except NoSuchElementException:
        artist_name.append("-") 
artist_name
# Out:
# ['Taylor Swift',
#  'Doja Cat',
#  'Mariah Carey',
#  'SZA',
#  'Zach Bryan Featuring Kacey Musgraves',
#  'Tate McRae',
#  'Brenda Lee',
#  'Taylor Swift',
#  'Tyla',
#  'Drake',
#  'Bobby Helms',
#  'Wham!',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Burl Ives',
#  'Drake Featuring J. Cole',
#  'Luke Combs',
#  'Doja Cat',
#  'Drake Featuring Sexyy Red & SZA',
#  'Jelly Roll',
#  'Jelly Roll With Lainey Wilson',
#  'Olivia Rodrigo',
#  'Paul Russell',
#  'Gunna',
#  'Drake Featuring J. Cole',
#  'Chris Stapleton',
#  'Andy Williams',
#  'Drake Featuring Yeat',
#  'Miley Cyrus',
#  'Dua Lipa',
#  'Usher, Summer Walker & 21 Savage',
#  'Dua Lipa',
#  'Tate McRae',
#  'Dean Martin',
#  'Billie Eilish',
#  'Noah Kahan',
#  'Bad Bunny',
#  'Jose Feliciano',
#  'Teddy Swims',
#  'Noah Kahan With Post Malone',
#  'Kelly Clarkson',
#  'Nat King Cole',
#  'Mitski',
#  'Doechii Featuring Kodak Black',
#  'The Ronettes',
#  'Miley Cyrus',
#  'Ariana Grande',
#  'SZA',
#  'Drake',
# ...

# %%
len(artist_name)
# Out:
# 99

# %%
rank=[]
try:
    rank_list=driver.find_elements(By.XPATH,"//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max']")
    for i in rank_list:
        rank.append(i.text)
except NoSuchElementException:
        rank.append("-") 
rank
# Out:
# ['2',
#  '2',
#  '1',
#  '29',
#  '3',
#  '16',
#  '17',
#  '60',
#  '4',
#  '50',
#  '6',
#  '13',
#  '8',
#  '10',
#  '-',
#  '53',
#  '5',
#  '4',
#  '15',
#  '8',
#  '-',
#  '1',
#  '38',
#  '51',
#  '32',
#  '33',
#  '9',
#  '43',
#  '10',
#  '38',
#  '44',
#  '34',
#  '25',
#  '7',
#  '7',
#  '35',
#  '14',
#  '9',
#  '16',
#  '7',
#  '13',
#  '34',
#  '19',
#  '23',
#  '21',
#  '21',
#  '23',
#  '10',
#  '18',
#  '23',
#  '-',
#  '1',
#  '12',
#  '18',
#  '-',
#  '34',
#  '26',
#  '7',
#  '22',
#  '13',
#  '20',
#  '26',
#  '28',
#  '15',
#  '11',
#  '2',
#  '-',
#  '1',
#  '-',
#  '26',
#  '27',
#  '19',
#  '31',
#  '8',
#  '24',
#  '6',
#  '-',
#  '27',
#  '39',
#  '15',
#  '34',
#  '23',
#  '-',
#  '22',
#  '-',
#  '39',
#  '30',
#  '9',
#  '35',
#  '29',
#  '-',
#  '23',
#  '29',
#  '45',
#  '-',
#  '19',
#  '36',
#  '50',
#  '58',
#  '7',
#  '-',
#  '1',
#  '-',
#  '1',
#  '46',
#  '11',
#  '42',
#  '17',
#  '47',
#  '4',
#  '33',
#  '4',
#  '40',
#  '3',
#  '-',
#  '1',
# ...

# %%
import numpy as np
df_r=pd.DataFrame(np.array(rank).reshape(100,2),columns=["Last_weel","Weeks on charts"])
df_r
# Out:
#    Last_weel Weeks on charts
# 0          1              28
# 1          -               1
# 2          2              15
# 3          4              49
# 4          3               3
# ..       ...             ...
# 95        91              13
# 96         -               1
# 97        98               5
# 98         -               1
# 99         -               1
#
# [100 rows x 2 columns]

# %%
df=pd.DataFrame({"songs":song,"Artist Name":artist_name})
df
# Out:
#                               songs                           Artist Name
# 0                      Cruel Summer                          Taylor Swift
# 1                Paint The Town Red                              Doja Cat
# 2   All I Want For Christmas Is You                          Mariah Carey
# 3                            Snooze                                   SZA
# 4             I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# ..                              ...                                   ...
# 94            Different 'Round Here      Riley Green Featuring Luke Combs
# 95                           Bongos         Cardi B & Megan Thee Stallion
# 96      But I Got A Beer In My Hand                            Luke Bryan
# 97                  Calling For You             Drake Featuring 21 Savage
# 98                Mi Ex Tenia Razon                               Karol G
#
# [99 rows x 2 columns]

# %% [markdown]
# # Question no.:6
# Scrape the details of Highest selling novels.
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre
#  Url - https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare

# %%
driver=webdriver.Chrome()
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Novels_data=[]
try:
    Novels_data_list=driver.find_elements(By.XPATH,"//td[@class='left']")
    for i in Novels_data_list:
        Novels_data.append(i.text)
except NoSuchElementException:
        Novels_data.append("-") 
Novels_data
# Out:
# ['1',
#  'Da Vinci Code,The',
#  'Brown, Dan',
#  '5,094,805',
#  'Transworld',
#  '2',
#  'Harry Potter and the Deathly Hallows',
#  'Rowling, J.K.',
#  '4,475,152',
#  'Bloomsbury',
#  '3',
#  "Harry Potter and the Philosopher's Stone",
#  'Rowling, J.K.',
#  '4,200,654',
#  'Bloomsbury',
#  '4',
#  'Harry Potter and the Order of the Phoenix',
#  'Rowling, J.K.',
#  '4,179,479',
#  'Bloomsbury',
#  '5',
#  'Fifty Shades of Grey',
#  'James, E. L.',
#  '3,758,936',
#  'Random House',
#  '6',
#  'Harry Potter and the Goblet of Fire',
#  'Rowling, J.K.',
#  '3,583,215',
#  'Bloomsbury',
#  '7',
#  'Harry Potter and the Chamber of Secrets',
#  'Rowling, J.K.',
#  '3,484,047',
#  'Bloomsbury',
#  '8',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Rowling, J.K.',
#  '3,377,906',
#  'Bloomsbury',
#  '9',
#  'Angels and Demons',
#  'Brown, Dan',
#  '3,193,946',
#  'Transworld',
#  '10',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Rowling, J.K.',
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.array(Novels_data).reshape(100,5),columns=["Rank","Title","Author","Volume Sales","Publisher"])
df
# Out:
#    Rank                                              Title            Author  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume Sales        Publisher
# ...

# %% [markdown]
# # Question no.: 7
# Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/ You have
# to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Chrome()
driver.get(" https://www.imdb.com/list/ls095964455/")

# %%
name=[]
try:
    name_list=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']")
    for i in name_list:
        name.append(i.text)
except NoSuchElementException:
        name.append("-") 
name
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016–2025)',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017–2023)',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014–2023)',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011– )',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016–2021)',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (I) (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
year=[]
try:
    year_list=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
    for i in year_list:
        year.append(i.text)
except NoSuchElementException:
        year.append("-") 
year
# Out:
# ['(2011–2019)',
#  '(2016–2025)',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017–2023)',
#  '(2005– )',
#  '(2014–2023)',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(I) (2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016–2022)',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018–2024)',
#  '(2019–2023)',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018–2024)',
#  '(2006–2013)',
#  '(2015–2023)',
#  '(1999– )',
#  '(2013–2023)',
#  '(2004–2010)',
# ...

# %%
genre=[]
try:
    genre_list=driver.find_elements(By.XPATH,"//span[@class='genre']")
    for i in genre_list:
        genre.append(i.text)
except NoSuchElementException:
        genre.append("-") 
genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Drama, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
vote=[]
try:
    vote_list=driver.find_elements(By.XPATH,"//span[@name='nv']")
    for i in vote_list:
        vote.append(i.text)
except NoSuchElementException:
        vote.append("-") 
vote
# Out:
# ['2,225,443',
#  '1,292,576',
#  '1,055,744',
#  '309,994',
#  '269,109',
#  '315,897',
#  '152,810',
#  '332,394',
#  '364,560',
#  '442,538',
#  '514,090',
#  '847,980',
#  '619,463',
#  '974,753',
#  '566,731',
#  '175,690',
#  '342,007',
#  '337,415',
#  '2,065,718',
#  '346,706',
#  '471,710',
#  '567,306',
#  '162,904',
#  '160,022',
#  '428,296',
#  '233,892',
#  '457,006',
#  '464,621',
#  '1,058,964',
#  '715,958',
#  '459,002',
#  '409,236',
#  '144,733',
#  '128,305',
#  '188,139',
#  '160,659',
#  '238,192',
#  '524,072',
#  '223,514',
#  '467,089',
#  '578,685',
#  '68,756',
#  '212,651',
#  '523,516',
#  '427,015',
#  '88,482',
#  '336,592',
#  '269,843',
#  '240,315',
#  '223,770',
#  '287,963',
#  '751,421',
#  '140,301',
#  '357,908',
#  '273,667',
#  '582,324',
#  '617,916',
#  '494,978',
#  '63,215',
#  '115,501',
#  '355,800',
#  '77,853',
#  '108,982',
#  '252,377',
#  '105,547',
#  '108,854',
#  '57,080',
#  '153,899',
#  '398,343',
#  '347,087',
#  '110,946',
# ...

# %%
run_time=[]
try:
    run_time_list=driver.find_elements(By.XPATH,"//span[@class='runtime']")
    for i in run_time_list:
        run_time.append(i.text)
except NoSuchElementException:
        run_time.append("-") 
run_time
# Out:
# ['4,189 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '5,702 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '3,030 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '5,280 min',
#  '4,576 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '3,804 min',
#  '1,455 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '5,076 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '2,109 min',
#  '7,788 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
# ...

# %%
rating=[]
try:
    rating_list=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']")
    for i in rating_list:
        rating.append(i.text)
except NoSuchElementException:
        rating.append("-") 
rating
# Out:
# ['9.2',
#  '8.7',
#  '8.1',
#  '7.5',
#  '7.6',
#  '8',
#  '6.5',
#  '7.6',
#  '7.5',
#  '7.5',
#  '8.2',
#  '8.2',
#  '8.7',
#  '9.1',
#  '8.5',
#  '7.4',
#  '7.7',
#  '8',
#  '9.5',
#  '8.1',
#  '8.4',
#  '8.3',
#  '8.1',
#  '7.7',
#  '8.7',
#  '7.7',
#  '8.8',
#  '8.6',
#  '8.9',
#  '8.3',
#  '8.4',
#  '8.5',
#  '8.3',
#  '6.2',
#  '7.5',
#  '8.2',
#  '7.8',
#  '8.5',
#  '7.9',
#  '8.5',
#  '9.1',
#  '6.5',
#  '8',
#  '8.7',
#  '8.7',
#  '7.2',
#  '8.3',
#  '8.5',
#  '7.8',
#  '7.5',
#  '7.7',
#  '8.7',
#  '6.8',
#  '8.2',
#  '8',
#  '8.3',
#  '8.8',
#  '8.7',
#  '6.7',
#  '8.3',
#  '8.3',
#  '7.3',
#  '6.8',
#  '8.4',
#  '7.4',
#  '8',
#  '7.9',
#  '6.8',
#  '8.7',
#  '8.4',
#  '6.5',
#  '7.9',
#  '8.9',
#  '7.8',
#  '7.6',
#  '9',
#  '8.1',
#  '8.5',
#  '8.2',
#  '7.3',
#  '8.7',
#  '8.2',
#  '6.4',
#  '6.3',
#  '8.6',
#  '7.8',
#  '7.3',
#  '7.7',
#  '7.2',
#  '8.4',
#  '6.5',
#  '8.2',
#  '8.6',
#  '9.3',
#  '7.8',
#  '7.5',
#  '7.8',
#  '8.1',
#  '7',
#  '8.6']

# %%
len(rating)
# Out:
# 2300

# %%
df=pd.DataFrame({"Name of show":name,"Year":year,"Genre of show":genre,"Votes":vote,"Run time":run_time,"Rating":rating})
df
# Out:
#                                       Name of show         Year  \
# 0                   1. Game of Thrones (2011–2019)  (2011–2019)
# 1                   2. Stranger Things (2016–2025)  (2016–2025)
# 2                  3. The Walking Dead (2010–2022)  (2010–2022)
# 3                    4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                           5. The 100 (2014–2020)  (2014–2020)
# ..                                             ...          ...
# 95                           96. Reign (2013–2017)  (2013–2017)
# 96  97. A Series of Unfortunate Events (2017–2019)  (2017–2019)
# 97                     98. Criminal Minds (2005– )     (2005– )
# 98           99. Scream: The TV Series (2015–2019)  (2015–2019)
# 99          100. The Haunting of Hill House (2018)       (2018)
#
#                Genre of show      Votes   Run time Rating
# 0   Action, Adventure, Drama  2,225,443  4,189 min    9.2
# 1     Drama, Fantasy, Horror  1,292,576     51 min    8.7
# ...

# %% [markdown]
# # Question no.: 8
# Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/ You
# have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute G) Year

# %%
driver=webdriver.Chrome()
driver.get("https://archive.ics.uci.edu/")

# %%
name=[]
try:
    name_list=driver.find_elements(By.XPATH,"//a[@class='link-hover link text-xl font-semibold']")
    for i in name_list:
        name.append(i.get_attribute("href"))
except NoSuchElementException:
        name.append("-") 
name
# Out:
# ['https://archive.ics.uci.edu/dataset/53/iris',
#  'https://archive.ics.uci.edu/dataset/45/heart+disease',
#  'https://archive.ics.uci.edu/dataset/2/adult',
#  'https://archive.ics.uci.edu/dataset/109/wine',
#  'https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic',
#  'https://archive.ics.uci.edu/dataset/34/diabetes',
#  'https://archive.ics.uci.edu/dataset/891/cdc+diabetes+health+indicators',
#  'https://archive.ics.uci.edu/dataset/890/aids+clinical+trials+group+study+175',
#  'https://archive.ics.uci.edu/dataset/892/tcga+kidney+cancers',
#  'https://archive.ics.uci.edu/dataset/887/national+health+and+nutrition+health+survey+2013-2014+(nhanes)+age+prediction+subset',
#  'https://archive.ics.uci.edu/dataset/882/large-scale+wave+energy+farm',
#  'https://archive.ics.uci.edu/dataset/880/support2']

# %%
Name=[]

# %%
for url in name:
    driver.get(url)
    time.sleep(2)

    try:       
        name_d=driver.find_elements(By.XPATH,"//h1[@class='text-3xl font-semibold text-primary-content']")
        for i in name_d:
            Name.append(i.text)
    except NoSuchElementException:
        Name.append("-")

# %%
Name
# Out:
# ['Iris',
#  'Heart Disease',
#  'Adult',
#  'Wine',
#  'Breast Cancer Wisconsin (Diagnostic)',
#  'Diabetes',
#  'CDC Diabetes Health Indicators',
#  'AIDS Clinical Trials Group Study 175',
#  'TCGA Kidney Cancers',
#  'National Health and Nutrition Health Survey 2013-2014 (NHANES) Age Prediction Subset',
#  'Large-scale Wave Energy Farm',
#  'SUPPORT2']

# %%
df_n=pd.DataFrame(Name,columns=["Name"])
df_n
# Out:
#                                                  Name
# 0                                                Iris
# 1                                       Heart Disease
# 2                                               Adult
# 3                                                Wine
# 4                Breast Cancer Wisconsin (Diagnostic)
# 5                                            Diabetes
# 6                      CDC Diabetes Health Indicators
# 7                AIDS Clinical Trials Group Study 175
# 8                                 TCGA Kidney Cancers
# 9   National Health and Nutrition Health Survey 20...
# 10                       Large-scale Wave Energy Farm
# 11                                           SUPPORT2

# %%
detail=[]

# %%
for url in name:
    driver.get(url)
    time.sleep(2)

    try:       
        d=driver.find_elements(By.XPATH,"//p[@class='text-md']")
        for i in d:
            detail.append(i.text)
    except NoSuchElementException:
        detail.append("-")

# %%
 detail
# Out:
# ['Tabular',
#  'Biology',
#  'Classification',
#  'Real',
#  '150',
#  '4',
#  'Multivariate',
#  'Health and Medicine',
#  'Classification',
#  'Categorical, Integer, Real',
#  '303',
#  '13',
#  'Multivariate',
#  'Social Science',
#  'Classification',
#  'Categorical, Integer',
#  '48842',
#  '14',
#  'Tabular',
#  'Physics and Chemistry',
#  'Classification',
#  'Integer, Real',
#  '178',
#  '13',
#  'Multivariate',
#  'Health and Medicine',
#  'Classification',
#  'Real',
#  '569',
#  '30',
#  'Multivariate, Time-Series',
#  'Health and Medicine',
#  'Classification',
#  'Categorical, Integer',
#  '1',
#  '20',
#  'Tabular, Multivariate',
#  'Health and Medicine',
#  'Classification',
#  'Categorical, Integer',
#  '253680',
#  '21',
#  'Tabular, Multivariate',
#  'Health and Medicine',
#  'Classification, Regression',
#  'Categorical, Integer',
#  '2139',
#  '23',
#  'Tabular, Multivariate',
#  'Health and Medicine',
#  'Classification, Clustering',
#  'Real',
#  '1024',
# ...

# %%
len(detail)
# Out:
# 72

# %%
import numpy as np
df=pd.DataFrame(np.array(detail).reshape(12,6),columns=["characteristic","subject","tasks","type","instances","features"])
df
# Out:
#                characteristic                subject  \
# 0                     Tabular                Biology
# 1                Multivariate    Health and Medicine
# 2                Multivariate         Social Science
# 3                     Tabular  Physics and Chemistry
# 4                Multivariate    Health and Medicine
# 5   Multivariate, Time-Series    Health and Medicine
# 6       Tabular, Multivariate    Health and Medicine
# 7       Tabular, Multivariate    Health and Medicine
# 8       Tabular, Multivariate    Health and Medicine
# 9                     Tabular    Health and Medicine
# 10               Multivariate            Engineering
# 11      Tabular, Multivariate    Health and Medicine
#
#                                 tasks                        type instances  \
# 0                      Classification                        Real       150
# 1                      Classification  Categorical, Integer, Real       303
# ...

# %%
result_df = pd.concat([df_n, df], axis=1)
result_df
# Out:
#                                                  Name  \
# 0                                                Iris
# 1                                       Heart Disease
# 2                                               Adult
# 3                                                Wine
# 4                Breast Cancer Wisconsin (Diagnostic)
# 5                                            Diabetes
# 6                      CDC Diabetes Health Indicators
# 7                AIDS Clinical Trials Group Study 175
# 8                                 TCGA Kidney Cancers
# 9   National Health and Nutrition Health Survey 20...
# 10                       Large-scale Wave Energy Farm
# 11                                           SUPPORT2
#
#                characteristic                subject  \
# 0                     Tabular                Biology
# 1                Multivariate    Health and Medicine
# 2                Multivariate         Social Science
# ...
